# %%
import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_auc_score,accuracy_score

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
movie_data = pd.read_csv('C:/Users/srinu/Desktop/grouplens-movies.csv')

# %%
movie_data
# Out:
#       Movie Id                                              Title  \
# 0            1                                   Toy Story (1995)
# 1            2                                     Jumanji (1995)
# 2            3                            Grumpier Old Men (1995)
# 3            4                           Waiting to Exhale (1995)
# 4            5                 Father of the Bride Part II (1995)
# 5            6                                        Heat (1995)
# 6            7                                     Sabrina (1995)
# 7            8                                Tom and Huck (1995)
# 8            9                                Sudden Death (1995)
# 9           10                                   GoldenEye (1995)
# 10          11                     American President, The (1995)
# 11          12                 Dracula: Dead and Loving It (1995)
# 12          13                                       Balto (1995)
# ...

# %%
movie_data = movie_data[['Genres','Price']]
movie_data
# Out:
#                                                Genres  Price
# 0         Adventure|Animation|Children|Comedy|Fantasy    280
# 1                          Adventure|Children|Fantasy    190
# 2                                      Comedy|Romance    150
# 3                                Comedy|Drama|Romance    210
# 4                                              Comedy    110
# 5                               Action|Crime|Thriller    130
# 6                                      Comedy|Romance    120
# 7                                  Adventure|Children    150
# 8                                              Action    120
# 9                           Action|Adventure|Thriller    170
# 10                               Comedy|Drama|Romance    200
# 11                                      Comedy|Horror    250
# 12                       Adventure|Animation|Children    230
# 13                                              Drama     90
# ...

# %%
movie_x = movie_data[['Genres']]
movie_y = movie_data[['Price']]

# %%
xtrain,xtest,ytrain, ytest = train_test_split(movie_x,movie_y,test_size=0.20)

# %%
xtrain.head()
# Out:
#                                 Genres
# 9115             Drama|Horror|Thriller
# 8083              Comedy|Drama|Romance
# 1006  Crime|Film-Noir|Mystery|Thriller
# 13                               Drama
# 8606               Action|Comedy|Crime

# %%
GenresEncoder = preprocessing.LabelEncoder()
GenresEncoder.fit(pd.DataFrame(xtrain[['Genres']]))
xtrain['Genres']=GenresEncoder.transform(xtrain[['Genres']])

# %%
Genresscaler = StandardScaler()
Genresscaler.fit(pd.DataFrame(xtrain[['Genres']]))
xtrain['Genres']= Genresscaler.transform(xtrain[['Genres']])

# %%
xtrain.head()
# Out:
#         Genres
# 9115  0.851542
# 8083  0.144289
# 1006  0.542118
# 13    0.669817
# 8606 -1.903799

# %%
xtest.head()
# Out:
#                      Genres
# 6795                  Drama
# 2717           Action|Drama
# 5     Action|Crime|Thriller
# 8996         Crime|Thriller
# 3337       Children|Musical

# %%
GenresEncoder.fit(pd.DataFrame(xtest[['Genres']]))
xtest['Genres']=GenresEncoder.transform(xtest[['Genres']])

# %%
Genresscaler.fit(pd.DataFrame(xtest[['Genres']]))
xtest['Genres']= Genresscaler.transform(xtest[['Genres']])

# %%
xtest.head()
# Out:
#         Genres
# 6795  0.706083
# 2717 -1.503995
# 5    -1.513731
# 8996  0.618459
# 3337 -0.121479

# %%
ytrain.head()
# Out:
#       Price
# 9115    270
# 8083     85
# 1006     85
# 13       90
# 8606    270

# %%
ytest.head()
# Out:
#       Price
# 6795    550
# 2717    550
# 5       130
# 8996    270
# 3337    120

# %%
logistic_regression = LogisticRegression()

# %%
logistic_regression.fit(xtrain,ytrain)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
#Predict on test data
ypred = logistic_regression.predict(xtest)

# %%
ypred
# Out:
# array([120, 120, 120, ..., 120, 120, 120], dtype=int64)

# %%
#Accuracy
print(accuracy_score(ytest,ypred))
# Out:
# 0.0958904109589041

# %% [markdown]
# **logistic regression is  possible to find the best accuracy**

# %%
decision_tree = tree.DecisionTreeClassifier()

# %%
decision_tree.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
#Check on test data
ypred = decision_tree.predict(xtest)
ypred_prob = decision_tree.predict_proba(xtest)
print(accuracy_score(ytest,ypred))
# Out:
# 0.07616438356164383

# %% [markdown]
# **decision tree is possible to find good accuracy**

# %%
linear_regression = LinearRegression()

# %%
linear_regression.fit(pd.DataFrame(xtrain), pd.DataFrame(ytrain))
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
yy_pred = linear_regression.predict(pd.DataFrame(xtest))

# %%
yy_pred
# Out:
# array([[223.29440073],
#        [223.32478998],
#        [223.32492385],
#        ...,
#        [223.28757319],
#        [223.32853843],
#        [223.30537834]])

# %%
print("Mean squared error : %.1f" % mean_squared_error(ytest,yy_pred))
# Out:
# Mean squared error : 12783.0

# %%
print('R2 Score : %.2f' % r2_score(ytest,yy_pred))
# Out:
# R2 Score : -0.00

# %% [markdown]
# **linear Regression is not possible to find the accuracy**

# %%
random_forest = RandomForestClassifier()
random_forest.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
Y_pred=random_forest.predict(xtest)
Y_pred_prob=random_forest.predict_proba(xtest)
print(accuracy_score(ytest,Y_pred))
# Out:
# 0.07452054794520548

# %% [markdown]
# **Random Forest is not possible to find the best accuracy**

# %% [markdown]
# # Therefore after using all the models, the logistic regression gives the best accuracy
